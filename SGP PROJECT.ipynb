# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt

from PIL import Image

# %%
breast_img = glob.glob('C:/Users/Dell/Downloads/Dataset/**/*.png', recursive = True)

for imgname in breast_img[:3]:
    print(imgname)

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of None cancer Images in IDC (-): {}' .format(non_num))
print('Number of cancer Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of None cancer Images in IDC (-): 397476
# Number of cancer Images in IDC (+) : 157572
# Total Number of Images : 555048

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(can_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, cv2.IMREAD_COLOR)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, cv2.IMREAD_COLOR)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (315144, 50, 50, 3)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.3, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (157572, 50, 50, 3)
# X_test shape : (63028, 50, 50, 3)
# X_predict shape : (94544, 50, 50, 3)
# y_train shape : (157572, 2)
# y_test shape : (63028, 2)
# y_true shape : (94544, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.20))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.20))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.20))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.20))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.20))



model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.7))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_206 (Conv2D)         (None, 50, 50, 32)        896
#
#  max_pooling2d_206 (MaxPooli  (None, 25, 25, 32)       0
#  ng2D)
#
#  dropout_225 (Dropout)       (None, 25, 25, 32)        0
#
#  conv2d_207 (Conv2D)         (None, 25, 25, 64)        18496
#
#  max_pooling2d_207 (MaxPooli  (None, 12, 12, 64)       0
#  ng2D)
#
#  dropout_226 (Dropout)       (None, 12, 12, 64)        0
#
#  conv2d_208 (Conv2D)         (None, 12, 12, 64)        36928
#
#  max_pooling2d_208 (MaxPooli  (None, 6, 6, 64)         0
#  ng2D)
#
#  dropout_227 (Dropout)       (None, 6, 6, 64)          0
#
#  conv2d_209 (Conv2D)         (None, 6, 6, 128)         73856
#
#  max_pooling2d_209 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  dropout_228 (Dropout)       (None, 3, 3, 128)         0
#
#  conv2d_210 (Conv2D)         (None, 3, 3, 128)         147584
#
#  max_pooling2d_210 (MaxPooli  (None, 1, 1, 128)        0
#  ng2D)
#
#  dropout_229 (Dropout)       (None, 1, 1, 128)         0
#
#  flatten_30 (Flatten)        (None, 128)               0
#
#  dense_59 (Dense)            (None, 128)               16512
#
#  dropout_230 (Dropout)       (None, 128)               0
#
#  dense_60 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 294,530
# Trainable params: 294,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 30, batch_size = 50)
# Out:
# Epoch 1/30
# 3152/3152 [==============================] - 555s 176ms/step - loss: 0.5336 - accuracy: 0.8446 - val_loss: 0.4644 - val_accuracy: 0.8654
# Epoch 2/30
# 3152/3152 [==============================] - 575s 182ms/step - loss: 0.3190 - accuracy: 0.8720 - val_loss: 0.3562 - val_accuracy: 0.8667
# Epoch 3/30
# 3152/3152 [==============================] - 576s 183ms/step - loss: 0.3012 - accuracy: 0.8797 - val_loss: 0.3291 - val_accuracy: 0.8707
# Epoch 4/30
# 3152/3152 [==============================] - 580s 184ms/step - loss: 0.2927 - accuracy: 0.8823 - val_loss: 0.3628 - val_accuracy: 0.8717
# Epoch 5/30
# 3152/3152 [==============================] - 580s 184ms/step - loss: 0.2864 - accuracy: 0.8840 - val_loss: 0.3131 - val_accuracy: 0.8836
# Epoch 6/30
# 3152/3152 [==============================] - 592s 188ms/step - loss: 0.2786 - accuracy: 0.8862 - val_loss: 0.3049 - val_accuracy: 0.8888
# Epoch 7/30
# 3152/3152 [==============================] - 675s 214ms/step - loss: 0.2730 - accuracy: 0.8894 - val_loss: 0.3303 - val_accuracy: 0.8866
# Epoch 8/30
# 3152/3152 [==============================] - 956s 303ms/step - loss: 0.2668 - accuracy: 0.8915 - val_loss: 0.2982 - val_accuracy: 0.8885
# Epoch 9/30
# 3152/3152 [==============================] - 597s 190ms/step - loss: 0.2630 - accuracy: 0.8931 - val_loss: 0.3062 - val_accuracy: 0.8964
# Epoch 10/30
# 3152/3152 [==============================] - 597s 189ms/step - loss: 0.2585 - accuracy: 0.8949 - val_loss: 0.3118 - val_accuracy: 0.8957
# Epoch 11/30
# 3152/3152 [==============================] - 602s 191ms/step - loss: 0.2546 - accuracy: 0.8959 - val_loss: 0.2807 - val_accuracy: 0.8982
# Epoch 12/30
# 3152/3152 [==============================] - 603s 191ms/step - loss: 0.2510 - accuracy: 0.8979 - val_loss: 0.2846 - val_accuracy: 0.8985
# Epoch 13/30
# 3152/3152 [==============================] - 593s 188ms/step - loss: 0.2484 - accuracy: 0.8981 - val_loss: 0.2865 - val_accuracy: 0.9009
# Epoch 14/30
# 3152/3152 [==============================] - 595s 189ms/step - loss: 0.2464 - accuracy: 0.8998 - val_loss: 0.2687 - val_accuracy: 0.8983
# Epoch 15/30
# 3152/3152 [==============================] - 590s 187ms/step - loss: 0.2440 - accuracy: 0.9011 - val_loss: 0.2658 - val_accuracy: 0.9043
# Epoch 16/30
# 3152/3152 [==============================] - 589s 187ms/step - loss: 0.2404 - accuracy: 0.9025 - val_loss: 0.2659 - val_accuracy: 0.9033
# Epoch 17/30
# 3152/3152 [==============================] - 590s 187ms/step - loss: 0.2378 - accuracy: 0.9041 - val_loss: 0.2614 - val_accuracy: 0.9017
# Epoch 18/30
# 3152/3152 [==============================] - 584s 185ms/step - loss: 0.2371 - accuracy: 0.9042 - val_loss: 0.2579 - val_accuracy: 0.9029
# Epoch 19/30
# 3152/3152 [==============================] - 581s 184ms/step - loss: 0.2340 - accuracy: 0.9059 - val_loss: 0.2536 - val_accuracy: 0.9083
# Epoch 20/30
# 3152/3152 [==============================] - 572s 181ms/step - loss: 0.2321 - accuracy: 0.9070 - val_loss: 0.2522 - val_accuracy: 0.9069
# Epoch 21/30
# 3152/3152 [==============================] - 573s 182ms/step - loss: 0.2303 - accuracy: 0.9075 - val_loss: 0.2554 - val_accuracy: 0.9061
# Epoch 22/30
# 3152/3152 [==============================] - 572s 182ms/step - loss: 0.2276 - accuracy: 0.9090 - val_loss: 0.2499 - val_accuracy: 0.9098
# Epoch 23/30
# 3152/3152 [==============================] - 570s 181ms/step - loss: 0.2273 - accuracy: 0.9090 - val_loss: 0.2562 - val_accuracy: 0.9063
# Epoch 24/30
# 3152/3152 [==============================] - 567s 180ms/step - loss: 0.2245 - accuracy: 0.9098 - val_loss: 0.2420 - val_accuracy: 0.9115
# Epoch 25/30
# 3152/3152 [==============================] - 567s 180ms/step - loss: 0.2235 - accuracy: 0.9095 - val_loss: 0.2391 - val_accuracy: 0.9098
# Epoch 26/30
# 3152/3152 [==============================] - 567s 180ms/step - loss: 0.2208 - accuracy: 0.9118 - val_loss: 0.2364 - val_accuracy: 0.9088
# Epoch 27/30
# 3152/3152 [==============================] - 571s 181ms/step - loss: 0.2199 - accuracy: 0.9119 - val_loss: 0.2316 - val_accuracy: 0.9130
# Epoch 28/30
# 3152/3152 [==============================] - 573s 182ms/step - loss: 0.2188 - accuracy: 0.9122 - val_loss: 0.2595 - val_accuracy: 0.9107
# Epoch 29/30
# 3152/3152 [==============================] - 574s 182ms/step - loss: 0.2169 - accuracy: 0.9129 - val_loss: 0.2279 - val_accuracy: 0.9167
# Epoch 30/30
# 3152/3152 [==============================] - 583s 185ms/step - loss: 0.2154 - accuracy: 0.9141 - val_loss: 0.2232 - val_accuracy: 0.9139

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 1261/1261 [==============================] - 73s 58ms/step - loss: 0.2232 - accuracy: 0.9139
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [158], in <cell line: 3>()
#       1 result = model.evaluate(X_test, y_test, batch_size = 50)
#       2 # print('Test Loss, Test Accuracy :', result)
# ----> 3 print(classification_report(result))
#
# TypeError: classification_report() missing 1 required positional argument: 'y_pred'

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

y_pred = []
true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1
        #append data for true predict
        y_pred.append('true')
    else:
        #append data for false predict
        y_pred.append('false')

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 91.38496361482484

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
